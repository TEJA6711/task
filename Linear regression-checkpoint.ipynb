# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data1 = pd.read_csv("NewspaperData.csv")
data1.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 944.0+ bytes

# %%
data1.isnull().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
data1.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
plt.figure(figsize=(6,3))
plt.title("Box plot for Daily sales")
plt.boxplot(data1["daily"],vert = False)
plt.show()

# %%
sns.histplot(data1['daily'],kde = True,stat='density',)
plt.show()

# %%
x= data1["daily"]
y= data1["sunday"]
plt.scatter(data1["daily"],data1["sunday"])
plt.xlim(0,max(x)+100)
plt.ylim(0,max(y)+100)
plt.show()

# %% [markdown]
# #### Observations
# - There are no missing values
# - The daily column values appears to be right-skewed
# - The sunday column values also appear to be right-skewed
# - There are two outliers in both column and also in sunday column as observed from

# %%
data1["daily"].corr(data1["sunday"])
# Out:
# 0.9581543140785462

# %%
data1[["daily","sunday"]].corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %% [markdown]
# ### Observations
# - The relation between x(daily)and y(sunday)is seen to be linear as seen from scatter plot
# -The correlaton is strong and positive with person's correation coffecient of o.958

# %% [markdown]
# #### Fit a Linear Regression Model

# %%
import statsmodels.formula.api as smf
model1 = smf.ols("sunday~daily",data = data1).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Mon, 03 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        10:41:09   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %% [markdown]
# #### Interpretation:
# - R square = 1 perfect filt(all variance explained).
# - R square = 0 Model does not explain any variance.
# - R square close to 1 good model fit
# - R square close to poor model fit

# %%
x = data1["daily"].values
y = data1["sunday"].values
plt.scatter(x,y,color = "m",marker = "o",s = 30)
b0 = 13.84
b1 = 1.33
y_hat = b0 +b1*x
plt.plot(x,y_hat,color = "g")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# - The probality(p-value)for intercept(beta_0)is 0.707 > 0.05
# - Therefore the intercept coefficient may not be that much significant in prediction
# - However the p_value for "daily"(beta_1)is 0.00 < 0.05
# - Therfore the beta_1 coefficient is highily significent and is contributint to prediction

# %%
model1.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
print(f'model t-values:\n{model1.tvalues}\n---------------\nmodel p-values:\n{model1.pvalues}')
# Out:
# model t-values:
# Intercept     0.386427
# daily        18.934840
# dtype: float64
# ---------------
# model p-values:
# Intercept    7.017382e-01
# daily        6.016802e-19
# dtype: float64

# %%
(model1.rsquared,model1.rsquared_adj)
# Out:
# (0.9180596895873295, 0.9154990548869336)

# %% [markdown]
# #### Predict for data point

# %%
newdata=pd.Series([200,300,1500])

# %%
data_pred=pd.DataFrame(newdata,columns=["daily"])
data_pred
# Out:
#    daily
# 0    200
# 1    300
# 2   1500

# %%
model1.predict(data_pred)
# Out:
# 0     281.778581
# 1     415.750057
# 2    2023.407766
# dtype: float64

# %%
pred = model1.predict(data1["daily"])
pred
# Out:
# 0      538.939509
# 1      706.442705
# 2      490.275710
# 3      333.431284
# 4      734.307432
# 5      996.884826
# 6      280.213795
# 7      352.279731
# 8      290.090172
# 9      323.546868
# 10     616.379041
# 11     400.438457
# 12     262.668890
# 13    1573.783417
# 14     609.447357
# 15     566.965002
# 16     378.613164
# 17    1061.219269
# 18    1633.852208
# 19    1119.786239
# 20     313.594128
# 21     489.224034
# 22     704.489401
# 23     309.195844
# 24     466.219792
# 25     277.920203
# 26     192.337885
# 27     514.901007
# 28     380.708478
# 29     777.960698
# 30     538.047259
# 31     284.270451
# 32     444.722729
# 33    1137.725020
# dtype: float64

# %%
# add predictd values as a column in data1
data1["Y_hat"] = pred
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
# computer the error values (residuals) and add as another column
data1["residuals"]= data1["sunday"]-data1["Y_hat"]
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat  \
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...
